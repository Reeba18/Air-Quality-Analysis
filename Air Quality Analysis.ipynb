# %% [markdown]
# # Air Quality Data Analysis

# %% [markdown]
# ## Air Quality Index

# %% [markdown]
# ![p1.png](attachment:p1.png)

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\reeba\OneDrive\Desktop\GitHub\air-quality-data.csv")

# %% [markdown]
# ## Data Exploration

# %%
df.columns
# Out:
# Index(['Timestamp', 'PM2.5'], dtype='object')

# %%
df.head()
# Out:
#           Timestamp   PM2.5
# 0  01-01-2018 00:00   90.19
# 1  01-01-2018 01:00   86.98
# 2  01-01-2018 02:00   86.06
# 3  01-01-2018 03:00   94.04
# 4  01-01-2018 04:00  108.78

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31861 entries, 0 to 31860
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  31861 non-null  object
#  1   PM2.5      31861 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 498.0+ KB

# %%
df.shape
# Out:
# (31861, 2)

# %%
df.dtypes
# Out:
# Timestamp     object
# PM2.5        float64
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum()                                 # check for nulls
# Out:
# Timestamp    0
# PM2.5        0
# dtype: int64

# %%
df[df.duplicated()]                               # check for duplicates
# Out:
# Empty DataFrame
# Columns: [Timestamp, PM2.5]
# Index: []

# %%
df['Timestamp']=pd.to_datetime(df['Timestamp'])   # change datatype of Timestamp from object to datetime

# %%
df['Year']=df['Timestamp'].dt.year
df['Month']=df['Timestamp'].dt.month
df['Hour']=df['Timestamp'].dt.hour                # add new columns viz Year,Month and Hour
df.columns
# Out:
# Index(['Timestamp', 'PM2.5', 'Year', 'Month', 'Hour'], dtype='object')

# %% [markdown]
# ## Data Transformation and Visualization

# %% [markdown]
# ### 1) Show the Year-wise average pollution with a Line chart

# %%
df.head()
# Out:
#             Timestamp   PM2.5  Year  Month  Hour
# 0 2018-01-01 00:00:00   90.19  2018      1     0
# 1 2018-01-01 01:00:00   86.98  2018      1     1
# 2 2018-01-01 02:00:00   86.06  2018      1     2
# 3 2018-01-01 03:00:00   94.04  2018      1     3
# 4 2018-01-01 04:00:00  108.78  2018      1     4

# %%
df1=df.groupby('Year')['PM2.5'].mean()        #form year-wise groups and compute the average of pollution
df1
# Out:
# Year
# 2018    54.468449
# 2019    49.511273
# 2020    42.386302
# 2021    44.850633
# Name: PM2.5, dtype: float64

# %%
df1.plot(kind='line',figsize=(15,5),ylabel='Mean PM 2.5',title='Year-wise Mean Air Pollution');           # plot a line chart using pandas lib

# %% [markdown]
# ### 2) Draw an area plot showing the average pollution against months

# %%
df.head()
# Out:
#             Timestamp   PM2.5  Year  Month  Hour
# 0 2018-01-01 00:00:00   90.19  2018      1     0
# 1 2018-01-01 01:00:00   86.98  2018      1     1
# 2 2018-01-01 02:00:00   86.06  2018      1     2
# 3 2018-01-01 03:00:00   94.04  2018      1     3
# 4 2018-01-01 04:00:00  108.78  2018      1     4

# %%
df2=df.groupby('Month')['PM2.5'].mean()          #form month-wise groups and compute the average of pollution

# %%
df2.plot(kind='area',figsize=(15,5),color='teal',ylabel='Mean PM 2.5',title='Month-wise Mean Air Pollution');            # plot a line chart using pandas lib

# %% [markdown]
# ### 3) Draw a bar graph to show the hour-wise average pollution

# %%
df.head()
# Out:
#             Timestamp   PM2.5  Year  Month  Hour
# 0 2018-01-01 00:00:00   90.19  2018      1     0
# 1 2018-01-01 01:00:00   86.98  2018      1     1
# 2 2018-01-01 02:00:00   86.06  2018      1     2
# 3 2018-01-01 03:00:00   94.04  2018      1     3
# 4 2018-01-01 04:00:00  108.78  2018      1     4

# %%
df.groupby('Hour')['PM2.5'].mean()                     #form hour-wise groups and compute the average of pollution
# Out:
# Hour
# 0     47.068769
# 1     46.403946
# 2     46.952281
# 3     49.150798
# 4     51.296204
# 5     51.908798
# 6     49.907545
# 7     47.518554
# 8     44.996127
# 9     42.681736
# 10    40.931766
# 11    39.393820
# 12    38.789992
# 13    39.323346
# 14    42.638162
# 15    47.500464
# 16    51.244844
# 17    53.669757
# 18    54.317363
# 19    54.120371
# 20    52.784130
# 21    51.383525
# 22    49.940615
# 23    48.538064
# Name: PM2.5, dtype: float64

# %%
df.groupby('Hour')['PM2.5'].mean().plot(kind='bar',figsize=(15,5),ylabel='Mean PM 2.5',color='purple',title='Hour-wise Average Air Pollution');    #create a bar graph

# %% [markdown]
# ### 4) In which month/s was the air  'Very Unhealthy'?

# %%
df.head()
# Out:
#             Timestamp   PM2.5  Year  Month  Hour
# 0 2018-01-01 00:00:00   90.19  2018      1     0
# 1 2018-01-01 01:00:00   86.98  2018      1     1
# 2 2018-01-01 02:00:00   86.06  2018      1     2
# 3 2018-01-01 03:00:00   94.04  2018      1     3
# 4 2018-01-01 04:00:00  108.78  2018      1     4

# %%
x=df[(df['PM2.5']>=150.5) & (df['PM2.5']<=250.4)]       #filtering data based on conditions
x
# Out:
#                 Timestamp   PM2.5  Year  Month  Hour
# 6     2018-01-06 17:00:00  150.89  2018      1    17
# 7     2018-11-07 21:00:00  245.63  2018     11    21
# 8     2018-11-08 00:00:00  175.19  2018     11     0
# 31    2018-11-07 22:00:00  232.03  2018     11    22
# 32    2018-11-08 01:00:00  169.15  2018     11     1
# 55    2018-11-07 20:00:00  223.21  2018     11    20
# 56    2018-11-08 03:00:00  160.34  2018     11     3
# 79    2018-11-07 18:00:00  212.56  2018     11    18
# 103   2018-11-07 19:00:00  207.41  2018     11    19
# 126   2018-11-07 17:00:00  183.19  2018     11    17
# 143   2018-11-07 23:00:00  173.67  2018     11    23
# 284   2018-01-13 16:00:00  165.45  2018      1    16
# 285   2018-01-13 17:00:00  177.58  2018      1    17
# 286   2018-01-13 18:00:00  175.32  2018      1    18
# 287   2018-01-13 19:00:00  166.60  2018      1    19
# 7578  2019-02-01 17:00:00  165.82  2019      2    17
# 7579  2019-02-01 18:00:00  157.99  2019      2    18
# 13697 2019-10-27 22:00:00  151.52  2019     10    22
# 13698 2019-10-27 23:00:00  219.07  2019     10    23
# 13699 2019-10-28 00:00:00  234.83  2019     10     0
# 13700 2019-10-28 01:00:00  230.05  2019     10     1
# 13701 2019-10-28 02:00:00  176.81  2019     10     2
# 22450 2020-11-14 18:00:00  183.39  2020     11    18
# 22451 2020-11-14 19:00:00  196.88  2020     11    19
# 22452 2020-11-14 20:00:00  178.61  2020     11    20
# 22455 2020-11-14 23:00:00  181.07  2020     11    23
# 22456 2020-11-15 00:00:00  193.80  2020     11     0
# 22457 2020-11-15 01:00:00  172.04  2020     11     1

# %%
x['Month'].value_counts()
# Out:
# 11    16
# 1      5
# 10     5
# 2      2
# Name: Month, dtype: int64

# %%
# Air quality was 'Very Unhealthy' in November.

# %% [markdown]
# ### 5) In which month was the air fresh(good) ?

# %%
x1=df[df['PM2.5']<12]                           #filtering

# %%
x1['Month'].value_counts()
# Out:
# 8    32
# 7     6
# 6     5
# 1     3
# 4     3
# 5     2
# Name: Month, dtype: int64

# %%
# Air quality was fresh in August.

# %% [markdown]
# ### 6) In year 2018, how many times was the AQI  recorded as 'Moderate'?

# %%
len(df[(df['Year']==2018) & (df['PM2.5']>=12.5)& (df['PM2.5']<=35.4)])
# Out:
# 2239

# %% [markdown]
# ### 7) How was the weather in the month of January and July?

# %%
df.head()
# Out:
#             Timestamp   PM2.5  Year  Month  Hour
# 0 2018-01-01 00:00:00   90.19  2018      1     0
# 1 2018-01-01 01:00:00   86.98  2018      1     1
# 2 2018-01-01 02:00:00   86.06  2018      1     2
# 3 2018-01-01 03:00:00   94.04  2018      1     3
# 4 2018-01-01 04:00:00  108.78  2018      1     4

# %%
z=df[df['Month'].isin([1,7])]                                   #filtering

# %%
z.groupby('Month')['PM2.5'].mean()                              # mean pollution values in Jan and July
# Out:
# Month
# 1    65.829067
# 7    31.884161
# Name: PM2.5, dtype: float64

# %%
# Air quality was unhealthy in January and moderate in July
